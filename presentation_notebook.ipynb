# %% [markdown]
# <a href="https://colab.research.google.com/github/alyssarose05/sql-murder-mystery/blob/main/presentation_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **SQL Murder Mystery**
# Project author: Alyssa Ayala

# %% [markdown]
# ![Screenshot 2024-12-03 100103.png](data:image/png;base64,...)

# %% [markdown]
# A horrific `murder` happened in `SQL City` on `January 15, 2018`. I am the Data Detective for their Police Department, and my job is to use the SQL database to find the details of the crime. Below are the steps I took to crack the case.

# %% [markdown]
# ## Conecting to the Police Department database
#
# Before I do anything, I first need to load the Poice Department database. To do so, I need to install the SQL datase from its GitHub repository.
#
# Please run the code below before proceeding to the next step. Expect to wait for about 30 seconds.

# %%
# %%capture --no-stderr
# @title Press Play { display-mode: "form" }

# Install TeachDB
# %pip install --quiet --upgrade git+https://github.com/freestackinitiative/teachingdb.git

# Set up TeachDB
from teachdb import TeachDB
db = TeachDB(database="sql_murder_mystery")
db.setup_notebook()
con = db.connection
# %sql con

# Maximize column width
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## See the tables in the database
#
# I need to learn the tables that I will be working with and their columns. This all comes from `information_schema.columns`, with their most important parts being `table_name`, `column_name`, and `data_type`.

# %%
# %%sql
#
# SELECT table_name, column_name, data_type
# FROM information_schema.columns
# ORDER BY table_name, column_name;
# Out:
#                 table_name            column_name data_type
# 0       crime_scene_report                   city   VARCHAR
# 1       crime_scene_report                   date   INTEGER
# 2       crime_scene_report            description   VARCHAR
# 3       crime_scene_report                   type   VARCHAR
# 4          drivers_license                    age   INTEGER
# 5          drivers_license               car_make   VARCHAR
# 6          drivers_license              car_model   VARCHAR
# 7          drivers_license              eye_color   VARCHAR
# 8          drivers_license                 gender   VARCHAR
# 9          drivers_license             hair_color   VARCHAR
# 10         drivers_license                 height   INTEGER
# 11         drivers_license                     id   INTEGER
# 12         drivers_license           plate_number   VARCHAR
# 13  facebook_event_checkin                   date   INTEGER
# 14  facebook_event_checkin               event_id   INTEGER
# ...

# %% [markdown]
# Now that I know about the tables in detail, I need to figure out their relationships to each other so that I can connect multiple tables. So far, it looks like the person's ID will be the **primary key**, while the gym and license IDs will have their separate IDs, making them the **foreign keys**.

# %% [markdown]
# ## Finding the police report
#
# The `crime_scene_report` table will have the police report on this exact case. We already know the `date`, `type`, and `city`, so we'll see what the `description` tells us.

# %%
# %%sql
#
# SELECT description
# FROM crime_scene_report
# WHERE date = '20180115' AND type = 'murder' AND city = 'SQL City';
# Out:
#                                                                                                                                                                                  description
# 0  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".

# %% [markdown]
# ## The first witness
#
# There were two witnesses, so now we will go further into these people to see exactly who they are and pull up their interviews based on their IDs. We need to connect the `person` and `interview` tables  on the person ID to accomplish this.
#
# The first one lives at the last house on `Northwestern Dr`:

# %%
# %%sql
#
# SELECT transcript
# FROM interview
# WHERE person_id IN (
#   SELECT id
#   FROM person
#   WHERE address_street_name = 'Northwestern Dr'
#   ORDER BY address_number DESC
#   LIMIT 1
# );
# Out:
#                                                                                                                                                                                                                         transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %% [markdown]
# **What we know about the murderer:**
#
# *   He is a **gold member** at the Get Fit Now Gym.
# *   The getaway car's plate includes 'H42W'.
#
# Let's look more into the possible cars. We can use a **subquery** to connect the person IDs  from the license ids and gym membership data, and ultimately **suspect names.**

# %%
# %%sql
#
# SELECT name
# FROM get_fit_now_member
# WHERE person_id IN (
#   SELECT id
#   FROM person
#   WHERE license_id IN (
#     SELECT id
#     FROM drivers_license
#     WHERE plate_number LIKE '%H42W%'
#   )
# );
# Out:
#             name
# 0  Jeremy Bowers

# %% [markdown]
# So our murderer is `Jeremy Bowers`: no second witness was needed. But let's quickly look at their details to see what information we can find for the sake of this project.
#
# For example, imagine multiple gym members had license plates with `H42W`. We could find an alternative approach to track down Jeremy.

# %% [markdown]
# ## The second witness
#
# From the crime scene report earlier, we know that the second witness's first name is `Annabel`, and she lives on `Franklin Ave`. Let's pull up her interview:

# %%
# %%sql
#
# SELECT transcript
# FROM interview
# WHERE person_id IN (
#   SELECT id
#   FROM person
#   WHERE name LIKE 'Annabel%' AND address_street_name = 'Franklin Ave'
# );
# Out:
#                                                                                                               transcript
# 0  I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %% [markdown]
# What we know from Annabel alone:
#
# *   He is a gym member.
# *   He worked out on January 9th.
#
# Let's see the details on Annabel's gym trip on January 9th:

# %%
# %%sql
#
# SELECT *
# FROM get_fit_now_check_in
# WHERE check_in_date = '20180109' AND membership_id IN (
#   SELECT id
#   FROM get_fit_now_member
#   WHERE person_id IN (
#     SELECT id
#     FROM person
#     WHERE name LIKE 'Annabel%' AND address_street_name = 'Franklin Ave'
#   )
# );
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         90081       20180109           1600            1700

# %% [markdown]
# We can use the check-in times to eliminate gym members as suspects. This would mean anyone who checked out before `1600` is _not_ a suspect, because Annabel could not have seen them. Also recall that the suspect has a gold membership, so the membership ID must begin with `48Z`.

# %%
# %%sql
#
# SELECT *
# FROM get_fit_now_check_in
# WHERE check_in_date = '20180109' AND check_out_time >'1600' AND membership_id != '90081';
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %% [markdown]
# This leaves us with two possible suspects. Both of them are gold members because their membership IDs begin with `48Z`, so that information from the first witness won't be useful. But let's see if knowing the license plate could help us.

# %%
# %%sql
#
# SELECT name
# FROM get_fit_now_member
# WHERE id IN (
#   SELECT membership_id
#   FROM get_fit_now_check_in
#   WHERE check_in_date = '20180109' AND check_out_time >='1600' AND membership_id != '90081')
# AND person_id IN (
#   SELECT id
#   FROM person
#   WHERE license_id IN (
#     SELECT id
#     FROM drivers_license
#     WHERE plate_number LIKE '%H42W%')
# );
# Out:
#             name
# 0  Jeremy Bowers

# %% [markdown]
# The same result is  `Jeremy Bowers`, just with specific gym check-in data information put into the query.

# %% [markdown]
# ## The real villain
#
# Even though `Jeremy Bowers` did the murder, was it really his idea? Was he perhaps manipulated in some way? I decided to give him the benefit of the doubt and look into his interview transcript:

# %%
# %%sql
#
# SELECT transcript
# FROM interview
# WHERE person_id IN (
#   SELECT id
#   FROM person
#   WHERE name = 'Jeremy Bowers'
# );
# Out:
#                                                                                                                                                                                                                                            transcript
# 0  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %% [markdown]
# According to Jeremy, he was hired by a woman to commit the crime. He doesn't know her name, but he gave many helpful details about her. Let's use this information to find out who hired him. Here's what we know about her:
# *   She is rich.
# *   She's either 5'5" or 5'7".
# *   She has `red` hair.
# *   She drives a `Tesla`, `Model S`.
# *   She attended the `SQL Symphony Concert` three times in December 2017.
#
# It's likely that we may not need all of these details. For example, her richness would be related to the `income` table, and her concerts would be related to the `facebook_event_checkin` table.
#
# Let's see what we can get based on her physical looks and concerts:

# %%
# %%sql
#
# SELECT name
# FROM person p
# JOIN drivers_license d
# ON p.license_id = d.id
# WHERE hair_color = 'red'
#   AND car_make = 'Tesla'
#   AND car_model = 'Model S'
#   AND height BETWEEN 65 AND 67
#   AND p.id IN (
#     SELECT person_id
#     FROM facebook_event_checkin
#     WHERE event_name = 'SQL Symphony Concert'
#   );
# Out:
#                name
# 0  Miranda Priestly

# %% [markdown]
# The real villain is **Miranda Priestly.** While Jeremy Bowers will also be punished, the Police Department's next steps would be to arrest Priestly and determine her punishment.
#
# Confirming Miranda's income and what Jeremy means by "a woman with a lot of money":

# %%
# %%sql
#
# SELECT annual_income
# FROM income
# WHERE ssn IN (
#   SELECT ssn
#   FROM person
#   WHERE name = 'Miranda Priestly'
# );
# Out:
#    annual_income
# 0         310000

# %% [markdown]
# Miranda has a six-figure salary: $310,000. This is indeed a good amount of money to make.
#
# This concludes my case.
